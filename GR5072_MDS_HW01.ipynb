# %% [markdown]
# # **GR5072 Modern Data Structures: Homework 1**
# ### **Done By: Wen Kai NG (C004641964)**
#
#
# #### 1. Create a Jupyter Notebook
#
# My favourite data science blog is [Datamites](https://datamites.com/blog/).
#
# ![datamites.jpg](attachment:datamites.jpg)
#
# They publish a range of interesting issues including data science technicalities, career guidance, and even courses for beginners.

# %% [markdown]
# #### 2. Markdown quote
#
# > "Success is no accident. It is hard work, perseverance, learning, studying, sacrifice and most of all, love of what you are doing or learning to do".
# > *- Pelé, Brazilian footballer*

# %% [markdown]
# #### 3. Latex formula and plot

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,1000)
y = x**0.5

plt.plot(x,y, 'r')

plt.show()

# %% [markdown]
# $x = (0,1000)$ <br/>
# $y = x^\frac{1}{2}$

# %% [markdown]
# #### 4. Markdown table
#
# | Useful Python Packages | Number of Github Stars |
# | ----------- | ----------- |
# | SciKit-Learn | 51.4k |
# | TensorFlow | 168k |
# | Matplotlib | 16.1k |
# | Pandas | 35.2k |
# | Numpy | 21.4k |

# %% [markdown]
# #### 5. Execute shell command

# %%
pwd
# Out:
# '/Users/ngwenkai/GR5072_MDS/GR5072_HW/Assignments'

# %% [markdown]
# #### 6. Run some external script
